# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# Requirement already satisfied: matplotlib in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Koke\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Koke\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Koke\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Koke\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Part 3 - Data Cleaning
df = pd.read_csv("train_u.csv")
# The columns with missing values are Gender , Dependents, Seld_Employed, LoanAmount,Loan_Amount_Term and Credit_History

#Gender
#We will check for the most frequent value then replace it with the null values especially since gender has a limited role in loan prediction

# Replace all null values for gender with the mode
df["Gender"] = df["Gender"].fillna(df["Gender"].mode()[0])


# Replace all null values for married with the mode
df["Married"] = df["Married"].fillna(df["Gender"].mode()[0])

#Handling Missing Dependants Values

# Checking the unique values to count number of each occurance
#df["Dependents"].unique

#Checking most frequent number od dependents 
#print(f" 0 has {df["Dependents"].value_counts()["0"]} occurences ")
#print(f" 1 has {df["Dependents"].value_counts()["1"]} occurences  ")
#print (f" 2 has {df["Dependents"].value_counts()["2"]} occurences  ")
#print(f" 3+ has {df["Dependents"].value_counts()["3+"]} occurences ")

#print(f" 0 appears more times on the columns of dependents so we will use it to replace of ill in the null values")

#Replacing empty dependant values with mode (0)

df["Dependents"] = df["Dependents"].fillna(df["Dependents"].mode()[0])

#Handling missing values for Self_Employed column

#df["Self_Employed"].mode()

# Replacing empty values with mode of the Self Employed column
df["Self_Employed"] = df["Self_Employed"].fillna(df["Self_Employed"].mode()[0])

# Handling LoanAmount missing values
# Since LoanAmount has bigger numbers we can use median as a replacement value
#df["LoanAmount"].median()

df["LoanAmount"] = df["LoanAmount"].fillna(df["LoanAmount"].median())


#Handling Loan_Amount_Term missing values
#We can use mode for this column since it has small values
#df["Loan_Amount_Term"].mode()

df["Loan_Amount_Term"] = df["Loan_Amount_Term"].fillna(df["Loan_Amount_Term"].mode()[0])



#Handling Credit History values
#We can use mode for this column since it has small values
#There is na within some of the tables
#df["Credit_History"].isna().sum()

df["Credit_History"] = df["Credit_History"].replace("NA", np.nan)

#Checking to see details pertaining Credit - History
#print(f" {df["Credit_History"].unique()}")
#print(f" {df["Credit_History"].isna().sum()}")
#print(f" {df["Credit_History"].dtype}")

df["Credit_History"] = df["Credit_History"].fillna(df["Credit_History"].mode()[0])
#Gender,Dependents, Self_Employed are objects, Well change these to str
# Loan_ Amount_Term should and credit history would ideally use int as a datatype
df["Gender"] = df["Gender"].astype("str")
df["Dependents"] = df["Dependents"].astype("str")
df["Self_Employed"] = df["Self_Employed"].astype("str")
df["Loan_Amount_Term"] = df["Loan_Amount_Term"].astype("int")
df["Credit_History"] = df["Credit_History"].astype("int")

df.to_csv("Training Cleaned Dataset.csv" , index=False)
